# %% [markdown]
# - Variables
# - Data types
# - Type Casting
# - print statements
# - input and round
# - we perform basic codes in 3 ways
#   - using proper variables
#   - using print statements
#   - using input and round

# %%
# import <module_name>
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # import <module_name>
# ----> 2 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import numpy as np
import random
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2 import random
#       3 import pandas
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import map
#
# ModuleNotFoundError: No module named 'map'

# %%
import time

# %% [raw]
# import math

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %% [markdown]
# **Packages and Modules**
#
# - Basically packages are like a container having different modules.
# - module is basically a python file containing the python code - functions, classes, methods, variables, etc.
# - packages basically cover these file under a single name and then we can just pass that package to different users without any errors
# - Assume that Ramesh has created 4 python files that has:
#   - Addition.py
#   - Multiplication.py
#   - Subtraction.py
#   - Division.py
# - Now, we assume there is a math_function named module which contain all these files alltogether.

# %% [markdown]
# - math_fucntions
#       add.py
#     sub.py
#     mul.py
#     div.py
#
# from math_functions import add
# from math_functions import sub
# from math_functions import mul
# from math_functions import div

# %% [markdown]
# **Random**

# %%
import random
(dir(random))
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# Step-1: import <Module Name>
# Step-2: dir(<Module Name>)
import random

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
import numpy
dir(numpy)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_get_promotion_state',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_no_nep50_warning',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_set_promotion_state',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
# ...

# %%
import pandas
dir(pandas)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
# ...

# %% [markdown]
# **Methods under a module also called as attribute**
#
# - random is module
#     - is a method or attribute
#     - random is a method or attribute
# - Every method purpose is different, the use case is different
# - If we want to call method or attribute, we need to call using module

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
import random
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
random.randintt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 random.randintt
#
# AttributeError: module 'random' has no attribute 'randintt'

# %%
import random
random.random()
# Out:
# 0.944175993292628

# %%
random.randint(1,100)
# Out:
# 33

# %%
import random
# dir(random)
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001FE3EE15870>>

# %%
# what is the work randint will do
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,23)
# Out:
# 10

# %% [markdown]
# **Practice**

# %%
import random

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001FE3EE15870>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,100)
# Out:
# 48

# %% [markdown]
# **Module: Random, Method: Random**

# %%
import random
dir(random)
random.random
help(random.random)
random.random()
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).
# 0.09943290713235597

# %% [markdown]
# **Module: Random, Method: Choice**

# %%
import random
dir(random)
random.choice
help(random.choice)
seq = 'Hey, My name is kunal saini, i am from delhi'
random.choice(l2)
random.choice(seq)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.
# 'a'

# %% [markdown]
# **Module: Random, Method: Shuffle**

# %%
import random
dir(random)
random.shuffle
help(random.shuffle)

l = [1,2,3,423,34,23,44,5342,342,6,563,3234,345]
l2 =[123,2,34,123,22,4,35,43,645,7324234,23,56,46,545,3]
random.shuffle(l2)
l2
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.
# [46, 545, 7324234, 34, 56, 123, 123, 645, 35, 43, 3, 23, 2, 4, 22]

# %% [markdown]
# **Module: Math, Method: e**

# %%
import math
dir(math)
math.e
# Out:
# 2.718281828459045

# %% [markdown]
# **Module: Math, Method: pi**

# %%
import math
dir(math)
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# **Module: Math, Method: sqrt**

# %%
import math
dir(math)
math.sqrt
help(math.sqrt)
math.sqrt(36)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.
# 6.0

# %% [markdown]
# **Module: math, Method: pow**

# %%
import math
dir(math)
math.pow
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# **Module: math, Method: sin**

# %%
import math
math.sin
math.sin(-60)
# Out:
# 0.3048106211022167

# %% [markdown]
# **Module: Math, Method: Ceil**

# %%
import math
math.ceil
math.ceil(67473.3)
# Out:
# 67474

# %% [markdown]
# **Module: Time, Method: Sleep**

# %%
import time
time.sleep
time.sleep(10)
print("My Name Is Kunal Saini.")
# Out:
# My Name Is Kunal Saini.

# %% [markdown]
# **Module: OS, Method: getcwd**

# %%
import os
os.getcwd
os.getcwd()
# Out:
# 'C:\\Users\\kunal\\OneDrive\\Documents\\Data Science with Gen AI\\Python_Sessions'

# %% [markdown]
# **Module: OS, Method: listdir**

# %%
import os
os.listdir
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Basic_questions.ipynb',
#  'GenAI_SQL_Application_creation.ipynb',
#  'input_eval_statements.ipynb',
#  'Kunal',
#  'Packages_and_Modules.ipynb',
#  'Print_statements.ipynb',
#  'Session_1.ipynb',
#  'Session_2.ipynb',
#  'Session_3.ipynb',
#  'Session_4.ipynb',
#  'Type_Casting.ipynb',
#  'Untitled.ipynb',
#  'Variables.ipynb']

# %%
os.mkdir('Kunal_Saini')

# %%
import keyword
dir(keyword)
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **Module: String**

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.Formatter()

# %%
string.Template(template)

# %%
string.__file__
# Out:
# 'C:\\ProgramData\\anaconda3\\Lib\\string.py'

# %%
string.__doc__
# Out:
# 'A collection of string constants.\n\nPublic module variables:\n\nwhitespace -- a string containing all ASCII whitespace\nascii_lowercase -- a string containing all ASCII lowercase letters\nascii_uppercase -- a string containing all ASCII uppercase letters\nascii_letters -- a string containing all ASCII letters\ndigits -- a string containing all ASCII decimal digits\nhexdigits -- a string containing all ASCII hexadecimal digits\noctdigits -- a string containing all ASCII octal digits\npunctuation -- a string containing all ASCII punctuation characters\nprintable -- a string containing all ASCII characters considered printable\n\n'

# %%
string.__loader__

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_uppercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
import random
random.randint(1,100)
# Out:
# 71

# %%
from random import randint

# %%
random
# Out:
# <module 'random' from 'C:\\ProgramData\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import langchain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 import langchain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
# !pip install langchain
# Out:
# Access is denied.

# %%
# !pip install cv2
# Out:
# Access is denied.

# %%
   # !conda install -c conda-forge langchain
# Out:
# Jupyter detected...
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     • https://repo.anaconda.com/pkgs/main
#     • https://repo.anaconda.com/pkgs/r
#     • https://repo.anaconda.com/pkgs/msys2
#
# To accept a channel's Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda tos accept --override-channels --channel CHANNEL
#
# To remove channels with rejected Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda config --remove channels CHANNEL

# %%
   # !pip install --user langchain
# Out:
# Access is denied.

# %%
   # !python -m venv langchain_env
   # Then activate it and install packages there
