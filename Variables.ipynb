# %% [markdown]
# WAP - take 3 variables a,b,c. Provide the values and find the average.

# %%
a = 100
b = 200
c = 273

average = (a+b+c)/3
average
# Out:
# 191.0

# %% [markdown]
# WAP - Calculate the area of circle

# %%
pi = 3.14
r = 6
area = pi*r*r
area
# Out:
# 113.03999999999999

# %% [markdown]
# WAP - ask the user, take bill amount and tip amount and calculate the total bill.

# %%
bill_amount = 12833.00
tip_amount = 123.43

total_amount = bill_amount + tip_amount
total_amount
# Out:
# 12956.43

# %% [markdown]
# WAP - ask the user to take the weight value and convert into pounds

# %%
weight = 4.5 
pound = weight*2.2
pound
# Out:
# 9.9

# %% [markdown]
# WAP - to convert dollars into indian currency

# %%
dollars = 348
indian_currency = dollars*80
indian_currency
# Out:
# 27840
