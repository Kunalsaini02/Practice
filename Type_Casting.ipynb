# %% [markdown]
# **Note**
#
# - When we provide a value from keyboard.
# - By default python takes **string data type**

# %%
n1 = input("Enter a number")
n1
type(n1)
# Out:
# Enter a number 23
# str

# %%
n2 = input("Enter a number")
n2
type(n2)
# Out:
# Enter a number one
# str

# %%
s1 = input('Enter a number1: ')
s2 = input('Enter a number2')
s1+s2
# Out:
# Enter a number1:  100
# Enter a number2 120
# '100120'

# %% [markdown]
# **Type Casting**
#
# - convert the one data type to another data type
# - int , float, str, bool
# - if a user provide one data type we can able to convert into other data type

# %%
a1 = int(input("Enter first number: "))
a2 = int(input("Enter second number: "))

a1+a2
# Out:
# Enter first number:  5373
# Enter second number:  26363
# 31736

# %% [markdown]
# **Integer to other data types**

# %%
n1 = 100
print(type(n1))
print(n1)
# Out:
# <class 'int'>
# 100

# %%
print(float(n1))
print(str(n1))
print(bool(n1))
# Out:
# 100.0
# 100
# True

# %%
print(float(-100))
print(str(-100))
print(bool(-100))
# Out:
# -100.0
# -100
# True

# %%
float(0)
# Out:
# False

# %%
n1 = 7.6

# %%
type(n1)
# Out:
# float

# %%
int(n1)
# Out:
# 7

# %% [markdown]
# **Float to integer**

# %%
str(10.5)
# Out:
# '10.5'

# %%
bool(10.5)
# Out:
# True

# %%
int(10.5)
# Out:
# 10

# %%
bool(-10.5), bool(-10.5), str(-10.5)
# Out:
# (True, True, '-10.5')

# %% [markdown]
# **String to other data type**

# %%
s1 = 'Kunal'
s1
# Out:
# 'Kunal'

# %%
s2 = '100'
s2
# Out:
# '100'

# %%
s3 = '100.4'
s3
# Out:
# '100.4'

# %%
int(s1), float(n1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 int(n1), float(n1), bool(n1)
#
# ValueError: invalid literal for int() with base 10: 'Kunal'

# %%
bool(n1)
# Out:
# True

# %%
int(s2), float(s2), bool(s2)
# Out:
# (100, 100.0, True)

# %%
int(s3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 int(s3)
#
# ValueError: invalid literal for int() with base 10: '100.4'

# %%
float(s3)
# Out:
# 100.4

# %%
bool(s3)
# Out:
# True

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
bool('0')
# Out:
# True

# %%
bool('Apple'), bool(''), bool('197384')
# Out:
# (True, False, True)

# %%
int('100.5') #error
int('100')   # 100

int('100.5')  vs int(100.5)
bool('0') vs bool(0)

# %% [markdown]
# **Bool to other**

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
str(True)
# Out:
# 'True'

# %%
str("True")
# Out:
# 'True'

# %%
int(False)
# Out:
# 0

# %%
float(False)
# Out:
# 0.0

# %%
str(False)
# Out:
# 'False'

# %%
str(100)
# Out:
# '100'
