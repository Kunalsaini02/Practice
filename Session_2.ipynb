# %% [markdown]
# python kernel: behaves like a servent, we will write a python code and the kernel will start excecute it.

# %%
for i in range(100):
    pass

# %%
import time 
time.sleep(5)
print('hai')
# Out:
# hai

# %%
a=10
print(a)
# Out:
# 10

# %% [markdown]
# - Star mark also indicates the kernel is busy
# - do no run any cells

# %%
n1=100
n1=200
n1
# Out:
# 200

# %%
a=10

# %%
b=20

# %%
a+b
# Out:
# 30

# %%
Number = 1000
# you did not run this

# %%
Number # i will run this 
#we will get the error -  this is because the upper cell is not already run. it will show error number not defined.
# Out:
# 1000

# %% [markdown]
# - Python is a step by step process
# - if we write 10 lines
# - all 10 lines sholuld be executed one by one
# - no matter you are having 10 lines in a cell or 10 different cells with one line each, all will be executed in order

# %%
import os
os.getcwd()
#cwd indicates the current working directory
# Out:
# 'C:\\Users\\kunal\\OneDrive\\Documents\\Data Science with Gen AI\\Python_Sessions'
