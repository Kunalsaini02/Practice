# %%
salary = 100000
tax_percentage = 10
tax_amount = salary*tax_percentage/100

# %%
tax_amount
# Out:
# 10000.0

# %% [markdown]
# Data Types

# %% [markdown]
# - int
# - float
# - complex
# - str
# - list
# - tuple
# - dict
# - set
# - frozenset
# - range
# - bytes
# - bytearray
# - memoryview
# - bool

# %% [markdown]
# **Integer Data Type**

# %%
number = 100
print(type(number))
print(number)
# Out:
# <class 'int'>
# 100

# %% [markdown]
# **Float Data Type**

# %%
n1 = 10.5
type(n1)
# Out:
# float

# %%
1e1
# Out:
# 10.0

# %%
print(1e1)
print(1e2)
print(2e3)
# Out:
# 10.0
# 100.0
# 2000.0

# %%
print(1e1, 1e+1)    #1*10
print(1e2, 1e+2)    #1*100
print(2e3, 2e+3)    #2*1000
# Out:
# 10.0 10.0
# 100.0 100.0
# 2000.0 2000.0

# %% [markdown]
# **String Data Type**

# %%
Hyderabad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Hyderabad
#
# NameError: name 'Hyderabad' is not defined

# %%
name = 'Kunal Saini'
Institute_Name = 'Naresh IT'
coaching_center = 'Hyderabad location'

# %%
name
# Out:
# 'Kunal Saini'

# %%
Institute_Name
# Out:
# 'Naresh IT'

# %%
coaching_center
# Out:
# 'Hyderabad location'

# %%
print(name)
print(Institute_Name)
print(coaching_center)
# Out:
# Kunal Saini
# Naresh IT
# Hyderabad location
