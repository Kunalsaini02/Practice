# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kunal\\OneDrive\\Documents\\Data Science with Gen AI\\Python_Sessions'

# %%
n1 = 100

# %%
n2 = 200

# %%
n1+n2
# Out:
# 300

# %% [markdown]
# empty square brackets cells are those which are not executed yet.

# %% [markdown]
# f

# %%
Numbe100 = 100

NUmber
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Numbe100 ()
#       2 NUmber
#
# NameError: name 'Numbe100' is not defined

# %%
NUMber = 400

# %%
NUMber
# Out:
# 400

# %%
number123 = 500

# %%
number123
# Out:
# 500

# %%
123number = 600
# Out:
#   Cell In[13], line 1
#     123number = 600
#       ^
# SyntaxError: invalid decimal literal

# %%
number = 1000

# %%
num@ber = 200
# Out:
#   Cell In[15], line 1
#     num@ber = 200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# - Special characters are not allowed
# - keyword cannot start with numeric

# %%
$number = 100
# Out:
#   Cell In[17], line 1
#     $number = 100
#     ^
# SyntaxError: invalid syntax

# %%
num@ber = 200 # F
$number = 100 # F
num_ber = 201 # P
areaofcircle = 478 # P
area_of_circle = 400 # P
are of circle = 100 # F
# Out:
#   Cell In[18], line 1
#     num@ber = 200 # F
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_ = 500

# %%
_
# Out:
# 500

# %%
if = 300
# Out:
#   Cell In[22], line 1
#     if = 300
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# - if is a reserved keywords, that is why we cannot use them as variable names.
# - some other keywords include : while, do, for , else, if , true, false, etc.

# %%
sum = 500

# %%
sum
# Out:
# 500

# %% [markdown]
# - sum, max, min are from math family, they have special purpose.
# - in python there are some inbuilt functions.
# - we will learn function in upcoming.

# %%
l = [1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
sum(l)
# Out:
# 10

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %%
imp = 0
for i in l:
    imp = imp+i

# %%
imp
# Out:
# 10

# %% [markdown]
# - Variables are case sensitive.
# - Variables does not include special characters.
# - Numbers as prefix not allowed.
# - Variables can have underscore.
# - Only underscore also possible.
# - reserved words or keywords cannot be used as variables.
# - only underscore only possible as variable.
# - inbuilt function cannot be used as variables.
