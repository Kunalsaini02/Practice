# %%
pi = 3.14
radius = 100
area_of_circle = pi*radius*radius

# %%
print(
# Out:
#   Cell In[6], line 1
#     print(
#           ^
# _IncompleteInputError: incomplete input

# %%
print()

# %%
print(")
# Out:
#   Cell In[4], line 1
#     print(")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("The area of the circle is")
# Out:
# The area of the circle is

# %%
print("The area of the circle is" = area_of_circle)
# Out:
#   Cell In[7], line 1
#     print("The area of the circle is" = area_of_circle)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
print("The area of the circle is", area_of_circle)
# Out:
# The area of the circle is 31400.0

# %%
print(f"The area of the circle is : {area_of_circel}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(f"The area of the circle is : {area_of_circel}")
#
# NameError: name 'area_of_circel' is not defined

# %%
print(f"The area of the circle is : {area_of_circle}")
# Out:
# The area of the circle is : 31400.0

# %%
print("The area of the circle is : {}".fotmat(area_of_circle))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("The area of the circle is : {}".fotmat(area_of_circle))
#
# AttributeError: 'str' object has no attribute 'fotmat'

# %%
print("The area of the circle is : {}".format(area_of_circle))
# Out:
# The area of the circle is : 31400.0

# %%
print("The area of the circle is : {}".format(area_of_circle)
# Out:
#   Cell In[13], line 1
#     print("The area of the circle is : {}".format(area_of_circle)
#                                                                  ^
# _IncompleteInputError: incomplete input

# %%
print("The area of the circle is : {}".format(area_of_circle))
# Out:
# The area of the circle is : 31400.0

# %% [markdown]
# **Round**

# %%
a = 2316
b = 2252
c = 3887
average  = (a+b+c)/3
average_value = round(average,2)

# %%
print("The average of the three numbers a, b and c is :", average)
# Out:
# The average of the three numbers a, b and c is : 2818.3333333333335

# %%
round(average, 3)
# Out:
# 2818.333

# %%
round(average)
# Out:
# 2818

# %%
round(average, 4)
# Out:
# 2818.3333

# %%
round(average, 1)
# Out:
# 2818.3

# %%
print("The average of {}, {}, {} is :{}".format(a,b,c,average_value))
# Out:
# The average of 2316, 2252, 3887 is :2818.33

# %% [markdown]
# **functions we are using right now:**
#
# - print()
# - type()
# - max()
# - min()
# - len()
# - sum()
# - round()

# %%
# () function call method
# whenever we miss the bracket
# it wil indicate to ways

# %% [markdown]
# - bonded method
# - function

# %%
import os
os.getcwd

#this is not showung any error instead asking the user to put the brackets after the function name to call the function.
# Out:
# <function nt.getcwd()>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kunal\\OneDrive\\Documents\\Data Science with Gen AI\\Python_Sessions'

# %%
name = 'Python' #hard coded

# we fixed the value
# we need to ask the user enter any value
# different users can enter same code

# %% [markdown]
# **Input**

# %%
name = input()
print('My name is :', name)
# Out:
#  Kunal Saini
# My name is : Kunal Saini

# %%
Name = input()
Age = input()
Place = input()
# Out:
#  Kunal Saini
#  23
#  Delhi

# %%
print('My name is {}. I am {} years old. I am from {}.'.format(Name, Age, Place))
# Out:
# My name is Kunal Saini. I am 23 years old. I am from Delhi.

# %%
print(f"My name is {Name}. I am {Age} years old. I am from {Place}.")
# Out:
# My name is Kunal Saini. I am 23 years old. I am from Delhi.

# %%
Name = input("Enter your name:")
Age = input("Enter you age: ")
Place = input("Enter your place: ")
# Out:
# Enter your name: Kunal Saini
# Enter you age:  23
# Enter your place:  Delhi

# %%
print(f"My name is {Name}. I am {Age} years old. I am from {Place}.")
# Out:
# My name is Kunal Saini. I am 23 years old. I am from Delhi.
